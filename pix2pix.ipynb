# %%
from pix2pix import Pix2pix
p2p = Pix2pix('/home/muaddib/Documents/DL/HW19/facades/trainA', '/home/muaddib/Documents/DL/HW19/facades/trainB')

# %%
lossD, lossG = p2p.train(1)
# Out:
# lossD: 0.570260 ;   lossG: -1.370569

# %%
out = p2p.test('/home/muaddib/Documents/DL/HW19/facades/testA','/home/muaddib/Documents/DL/HW19/facades/testB')
